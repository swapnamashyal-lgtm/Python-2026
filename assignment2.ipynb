# %% [markdown]
# <a href="https://colab.research.google.com/github/swapnamashyal-lgtm/Python-2026/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter the number"))
print(num)
# Out:
# Enter the number80
# 80

# %%
num = 10
print(num)
# Out:
# 10

# %%
num= int(input("Enter the number: "))
print(num)
# Out:
# Enter the number: 10
# 10

# %%
num= int(input("enter the first number; "))
num= int(input("enter the second number"))
print("sum = ", num+num)
# Out:
# enter the first number; 20
# enter the second number30
# sum =  60

# %%
num = int(input("enter first number: "))
num = int(input("enter second number: "))
print("result =",num*num)
# Out:
# enter first number: 20
# enter second number: 30
# result = 900

# %%
a = int(input("enter first number: "))
b = int(input("enter second nmber:"))
print("result =", a * b)
# Out:
# enter first number: 10
# enter second nmber:40
# result = 400

# %%
a = int(input("enter first number: "))
b = int(input("enter second number: "))
print("modules =", a%b)
# Out:
# enter first number: 4
# enter second number: 8
# modules = 4

# %%
for i in range(1, 6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
a = int(input("enter first number: "))
b = int(input("enter second number: "))

if a > b:
  print("Grater number is", a)
else:
  print("Grater nmber is", b)
# Out:
# enter first number: 40
# enter second number: 50
# Grater nmber is 50

# %%
def ad(a, b):
    return a + b

print(5, 3)
# Out:
# 5 3

# %%
num = int(input("Enter a number: "))

if num > 0:
     print("Positive numbr")
elif num < 0:
    print("Negitive number")
else:
  print("Zero")
# Out:
# Enter a number: 40
# Positive numbr
